# %%
import pandas as pd
movies_df = pd.read_csv("datasets/merged_ratings_movies.csv")
print(movies_df.columns)
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp', 'title', 'movie_year',
#        'title_clean', 'user_count', 'user_mean', 'user_std', 'movie_count',
#        'movie_mean', 'movie_std', 'ts_year', 'ts_month', 'ts_dayofweek',
#        'user_movie_mean_diff'],
#       dtype='object')
